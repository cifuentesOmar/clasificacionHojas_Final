# %% [markdown]
# ## 1. Se importan las librerias

# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import keras
from keras.utils import to_categorical
from keras.models import Sequential,Model
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from keras import backend as K
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc, plot_confusion_matrix
# Agregadas
from sklearn.datasets import make_classification
from sklearn.svm import SVC
import tensorflow as tf
from tensorflow.keras.utils import img_to_array
import cv2
from sklearn.preprocessing import LabelBinarizer
import pickle
from focal_loss import BinaryFocalLoss
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score
import pandas as pd

# %% [markdown]
# ## 2. Parametrizaciones

# %%
dirname = os.path.join("FotosOriginales")
imgpath = dirname + os.sep 
HEIGHT=128
WIDTH=128
DEPTH=3
DEFAULT_IMAGE_SIZE = tuple((WIDTH, HEIGHT))
INIT_LR = 1e-3
epochs = 30
batch_size = 16
inputShape = (HEIGHT, WIDTH, DEPTH)
chanDim = -1

# %% [markdown]
# ## 3. Se cargan las imágenes

# %%
images = []
directories = []
dircount = []
prevRoot=''
cant=0

print("Leyendo imágenes de ",imgpath)

for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            image = plt.imread(filepath)
            res = cv2.resize(image, dsize=(WIDTH, HEIGHT), interpolation=cv2.INTER_CUBIC)
            images.append(res)
            b = "Leyendo..." + str(cant)
            print (b, end="\r")
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
dircount.append(cant)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print("Imagenes en directorio NoSana", dircount[0])
print("Imagenes en directorio Sana", dircount[1])
print('Suma Total de imagenes en subdirs:',sum(dircount))
# Out:
# Leyendo imágenes de  FotosOriginales/
# FotosOriginales/NoSana 1
# FotosOriginales/Sana 15
# Directorios leidos: 2
# Imagenes en cada directorio [16, 72]
# Imagenes en directorio NoSana 16
# Imagenes en directorio Sana 72
# Suma Total de imagenes en subdirs: 88

# %% [markdown]
# ## 4. Se crean etiquetas y clases

# %%
labels=[]
indice=0
for cantidad in dircount:
    for i in range(cantidad):
        labels.append(indice)
    indice=indice+1
print("Cantidad etiquetas creadas: ",len(labels))
etiquetas=[]
indice=0
for directorio in directories:
    name = directorio.split(os.sep)
    print(indice , name[len(name)-1])
    etiquetas.append(name[len(name)-1])
    indice=indice+1

y = np.array(labels)
X = np.array(images, dtype=np.uint8) #Lista a numpy

classes = np.unique(y)
nClasses = len(classes)
print('Número total de salidas : ', nClasses)
print('Clases de salida : ', classes)
# Out:
# Cantidad etiquetas creadas:  88
# 0 NoSana
# 1 Sana
# Número total de salidas :  2
# Clases de salida :  [0 1]

# %% [markdown]
# ## 5. Distribución de clases

# %%
font = {'size'   : 12}
plt.rc('font', **font)

clases = list(etiquetas)
valores = list([dircount[0], dircount[1]])
fig = plt.figure(figsize = (5, 3))
 
plt.bar(clases, valores, color =["red", "green"], width = 0.5)
plt.xlabel("Clases")
plt.ylabel("Muestras")
plt.title("Distribución de clases")
plt.text(-0.2, dircount[0]-15,str(round(dircount[0]/(dircount[0]+dircount[1])*100,2)) + "% (" + str(dircount[0]) + ")", fontsize=10)
plt.text(0.8, dircount[1]-15, str(round(dircount[1]/(dircount[0]+dircount[1])*100,2)) + "% (" + str(dircount[1]) + ")", fontsize=10)
plt.show()

# %% [markdown]
# ## 6. Se crean los sets de Entrenamiento y Test, Validación y Preprocesar

# %%
#Crear los grupos de entrenamiento y testing
train_X,test_X,train_Y,test_Y = train_test_split(X,y,test_size=0.2)
print('Training data shape : ', train_X.shape, train_Y.shape)
print('Testing data shape : ', test_X.shape, test_Y.shape)

train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X / 255.
test_X = test_X / 255.

# Cambia las etiquetas desde categorical a one-hot
train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)

# Muestra las etiquetas cambiadas desde category a one-hot
print('Etiqueta original:', train_Y[0])
print('Convertida a one-hot:', train_Y_one_hot[0])

train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_Y_one_hot, test_size=0.2, random_state=13)

print(train_X.shape,valid_X.shape,train_label.shape,valid_label.shape)
# Out:
# Training data shape :  (70, 128, 128, 3) (70,)
# Testing data shape :  (18, 128, 128, 3) (18,)
# Etiqueta original: 1
# Convertida a one-hot: [0. 1.]
# (56, 128, 128, 3) (14, 128, 128, 3) (56, 2) (14, 2)

# %%
np.save("test_X_originales", test_X)
np.save("test_Y_one_hot_originales", test_Y_one_hot)
np.save("test_Y_originales", test_Y)

# %%
test_X_combinado = np.load("test_X_originales.npy")

# %% [markdown]
# ## 7. Se crea la red

# %%
# Calculo de métrica F1
def f1_metric(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

model = Sequential()

# Modelo
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=inputShape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(nClasses, activation='softmax'))

model.summary()

#Funciones de pérdida
perd = "categorical_crossentropy"

#Optimizadores
opt = keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / epochs)

model.compile(loss=perd, optimizer=opt,metrics=['accuracy', f1_metric])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 63, 63, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 21, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 21, 21, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 10, 10, 64)        0
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 128)               819328
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 875,906
# Trainable params: 875,906
# Non-trainable params: 0
# _________________________________________________________________
# 2022-12-17 08:57:50.474284: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 8. Se entrena la red

# %%
history = model.fit(train_X, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label))

# Se guarda el modelo
model.save("modelo_originales.h5")
# Out:
# Epoch 1/30
# 4/4 [==============================] - 2s 306ms/step - loss: 1.0901 - accuracy: 0.6607 - f1_metric: 0.7031 - val_loss: 0.6207 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 2/30
# 4/4 [==============================] - 1s 224ms/step - loss: 0.5587 - accuracy: 0.8036 - f1_metric: 0.7969 - val_loss: 0.5299 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 3/30
# 4/4 [==============================] - 1s 218ms/step - loss: 0.5436 - accuracy: 0.7857 - f1_metric: 0.7812 - val_loss: 0.3942 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 4/30
# 4/4 [==============================] - 1s 193ms/step - loss: 0.5594 - accuracy: 0.7857 - f1_metric: 0.7969 - val_loss: 0.5012 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 5/30
# 4/4 [==============================] - 1s 212ms/step - loss: 0.5682 - accuracy: 0.7857 - f1_metric: 0.7500 - val_loss: 0.5164 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 6/30
# 4/4 [==============================] - 1s 234ms/step - loss: 0.5368 - accuracy: 0.7857 - f1_metric: 0.7812 - val_loss: 0.5424 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 7/30
# 4/4 [==============================] - 1s 253ms/step - loss: 0.5507 - accuracy: 0.7857 - f1_metric: 0.7812 - val_loss: 0.4789 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 8/30
# 4/4 [==============================] - 1s 238ms/step - loss: 0.4829 - accuracy: 0.7857 - f1_metric: 0.7812 - val_loss: 0.4652 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 9/30
# 4/4 [==============================] - 1s 256ms/step - loss: 0.5508 - accuracy: 0.7857 - f1_metric: 0.7812 - val_loss: 0.4401 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 10/30
# 4/4 [==============================] - 1s 220ms/step - loss: 0.4954 - accuracy: 0.7857 - f1_metric: 0.7969 - val_loss: 0.4652 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 11/30
# 4/4 [==============================] - 1s 220ms/step - loss: 0.4689 - accuracy: 0.7857 - f1_metric: 0.7656 - val_loss: 0.4370 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 12/30
# 4/4 [==============================] - 1s 204ms/step - loss: 0.4752 - accuracy: 0.7679 - f1_metric: 0.7500 - val_loss: 0.4378 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 13/30
# 4/4 [==============================] - 1s 242ms/step - loss: 0.4336 - accuracy: 0.7857 - f1_metric: 0.8125 - val_loss: 0.3659 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 14/30
# 4/4 [==============================] - 1s 204ms/step - loss: 0.5635 - accuracy: 0.7857 - f1_metric: 0.7969 - val_loss: 0.5077 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 15/30
# 4/4 [==============================] - 1s 200ms/step - loss: 0.4743 - accuracy: 0.8214 - f1_metric: 0.7969 - val_loss: 0.4572 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 16/30
# 4/4 [==============================] - 1s 221ms/step - loss: 0.4401 - accuracy: 0.8036 - f1_metric: 0.8281 - val_loss: 0.3817 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 17/30
# 4/4 [==============================] - 1s 236ms/step - loss: 0.4059 - accuracy: 0.8214 - f1_metric: 0.7969 - val_loss: 0.4425 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 18/30
# 4/4 [==============================] - 1s 251ms/step - loss: 0.4208 - accuracy: 0.8214 - f1_metric: 0.7969 - val_loss: 0.4678 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 19/30
# 4/4 [==============================] - 1s 327ms/step - loss: 0.4448 - accuracy: 0.8214 - f1_metric: 0.7969 - val_loss: 0.4059 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 20/30
# 4/4 [==============================] - 1s 255ms/step - loss: 0.3663 - accuracy: 0.8571 - f1_metric: 0.8281 - val_loss: 0.3166 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 21/30
# 4/4 [==============================] - 1s 256ms/step - loss: 0.3365 - accuracy: 0.8750 - f1_metric: 0.8750 - val_loss: 0.3853 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 22/30
# 4/4 [==============================] - 1s 221ms/step - loss: 0.3267 - accuracy: 0.9107 - f1_metric: 0.9062 - val_loss: 0.1707 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 23/30
# 4/4 [==============================] - 1s 276ms/step - loss: 0.3593 - accuracy: 0.8750 - f1_metric: 0.8750 - val_loss: 0.2571 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 24/30
# 4/4 [==============================] - 1s 329ms/step - loss: 0.3463 - accuracy: 0.9107 - f1_metric: 0.9062 - val_loss: 0.2813 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 25/30
# 4/4 [==============================] - 1s 265ms/step - loss: 0.3261 - accuracy: 0.8929 - f1_metric: 0.9062 - val_loss: 0.2600 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 26/30
# 4/4 [==============================] - 1s 225ms/step - loss: 0.3529 - accuracy: 0.8393 - f1_metric: 0.8438 - val_loss: 0.2903 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 27/30
# 4/4 [==============================] - 1s 306ms/step - loss: 0.3000 - accuracy: 0.8929 - f1_metric: 0.8750 - val_loss: 0.2364 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 28/30
# 4/4 [==============================] - 1s 244ms/step - loss: 0.2815 - accuracy: 0.9107 - f1_metric: 0.9062 - val_loss: 0.2401 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 29/30
# 4/4 [==============================] - 1s 235ms/step - loss: 0.2480 - accuracy: 0.9643 - f1_metric: 0.9688 - val_loss: 0.1777 - val_accuracy: 1.0000 - val_f1_metric: 1.0000
# Epoch 30/30
# 4/4 [==============================] - 1s 233ms/step - loss: 0.1960 - accuracy: 0.9464 - f1_metric: 0.9375 - val_loss: 0.1766 - val_accuracy: 1.0000 - val_f1_metric: 1.0000

# %% [markdown]
# ## 9. Análisis de métricas de rendimiento

# %%
y_pred = model.predict(test_X)
y_pred.shape
test_Y.shape
y_pred[0,:].sum()
# Out:
# 1/1 [==============================] - 0s 233ms/step
# 1.0

# %% [markdown]
# ## 10. Resultados obtenidos

# %%
test_eval = model.evaluate(test_X, test_Y_one_hot, verbose=1)

print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
print('Test F1:', test_eval[2])
# Out:
# 1/1 [==============================] - 0s 150ms/step - loss: 0.2088 - accuracy: 0.9444 - f1_metric: 0.9444
# Test loss: 0.20884637534618378
# Test accuracy: 0.9444444179534912
# Test F1: 0.9444443583488464

# %% [markdown]
# ## 11. Gráficos

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

f1 = history.history['f1_metric']
val_f1 = history.history['val_f1_metric']

epochs = range(1, len(acc) + 1)

# Accuracy de los datos de entrenamiento y datos de prueba
plt.plot(epochs, acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.show()

# Pérdida de datos de entrenamiento y datos de prueba
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# F1 de los datos de entrenamiento y datos de prueba
plt.plot(epochs, f1, 'b', label='Training f1')
plt.plot(epochs, val_f1, 'r', label='Validation f1')
plt.title('Training and Validation f1')
plt.legend()
plt.show()

# %% [markdown]
# ## 12. Matriz de confusión

# %%
def show_metrics(y_pred,th):
    cm = confusion_matrix(test_Y, y_pred.argmax(axis=1)>th)
    #print(cm)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No Sana", "Sana"])
    disp.plot(cmap=plt.cm.Greens)
    plt.title('Matriz de confusión del clasificador')
    plt.xlabel('Valores predichos')
    plt.ylabel('Valores Verdaderos')
    plt.show()
    d = classification_report(test_Y, y_pred.argmax(axis=1) > th,output_dict=True)
    display(pd.DataFrame.from_dict(d))
    return y_pred, d

a, mi_dicc = show_metrics(y_pred,.5)
# Out:
#                   0          1  accuracy  macro avg  weighted avg
# precision  1.000000   0.933333  0.944444   0.966667      0.948148
# recall     0.750000   1.000000  0.944444   0.875000      0.944444
# f1-score   0.857143   0.965517  0.944444   0.911330      0.941434
# support    4.000000  14.000000  0.944444  18.000000     18.000000

# %%
#print(pd.DataFrame(mi_dicc).to_latex(index=False))

# %% [markdown]
# ## 13. Puesta a prueba del modelo

# %%
from tensorflow.keras.preprocessing import image

#6 Hojas SANAS
#img=image.load_img("FotosCombinadas/Sana/augmented_35_3786006.jpeg",target_size=DEFAULT_IMAGE_SIZE)
#img=image.load_img("FotosAumentadas/sana/augmented_10_1786905.jpeg",target_size=DEFAULT_IMAGE_SIZE)
#img=image.load_img("FotosOriginales/Sana/IMG_7912.jpeg",target_size=DEFAULT_IMAGE_SIZE)


#6 Hojas NO SANAS
img=image.load_img("FotosCombinadas/NoSana/augmented_0_3427922.jpeg",target_size=DEFAULT_IMAGE_SIZE)
#img=image.load_img("FotosAumentadas/NoSana/augmented_0_8857250.jpeg",target_size=DEFAULT_IMAGE_SIZE)
#img=image.load_img("FotosOriginales/NoSana/IMG_7917.jpeg",target_size=DEFAULT_IMAGE_SIZE)

plt.imshow(img)
plt.show()

x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
images=np.vstack([x])
pred=model.predict(images,batch_size=16)
print(etiquetas)
print(pred)
if pred[0][0]>0.5:
    category="No Sana"
elif pred[0][1]>0.5:
    category="Sana"
        
print(category)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# ['NoSana', 'Sana']
# [[1. 0.]]
# No Sana
